# %%
# %matplotlib inline
from test_funcs import Beale, GoldsteinPrice
from visualizations import plot_cost_function_3d, plot_contourf

# %%
cost_f = GoldsteinPrice()

# %%
plot_cost_function_3d(cost_f)

# %%
plot_contourf(cost_f, figsize=[7,7])
# Out:
# [[0.3889215  0.47628094 0.63606548 ... 0.30659087 0.27012043 0.25490177]
#  [0.27767892 0.34407281 0.46543242 ... 0.2772784  0.24790248 0.23618499]
#  [0.19022325 0.22234082 0.29881996 ... 0.25645861 0.23364482 0.22533743]
#  ...
#  [0.33641911 0.30288328 0.2720434  ... 0.58098583 0.59638721 0.60181577]
#  [0.29410925 0.26714898 0.24257637 ... 0.54706622 0.56679859 0.58239447]
#  [0.27309045 0.24934075 0.22832197 ... 0.52769968 0.54757438 0.56537085]]
# (<Figure size 504x504 with 1 Axes>, <AxesSubplot:>)
