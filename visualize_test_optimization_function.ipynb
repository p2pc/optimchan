# %%
# %matplotlib inline
from test_funcs import Beale, GoldsteinPrice, Rosenbrock, Rastrigin, Ackley
from visualizations import plot_cost_function_3d, plot_contourf

# %%
rosenbrock_func = Rosenbrock()
beale_func = Beale()
goldstein_price_func = GoldsteinPrice()
rastrigin_func = Rastrigin()
ackley_func = Ackley()

# %% [markdown]
# Hàm log-beale được định nghĩa như sau:
#
# $$
# f(x,y) = \displaystyle\frac{\log{\left(1+{(1.5-x+xy)}^2 + {(2.25-x+xy^2)}^2 + {(2.625-x+xy^3)}^2\right)}}{10}
# $$

# %%
plot_cost_function_3d(beale_func, figsize=[12, 8])

# %%
plot_contourf(beale_func, figsize=[8, 8])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# Hàm Rosenbrock với n = 2
#
# $$
# f(x) = \frac{log\left(\sum_{i=1}^{n-1}\left(100(x_{i+1}-x_i^2)^2+(1-x_i)^2\right)\right)}{10}
# $$

# %%
plot_cost_function_3d(rosenbrock_func, figsize=[12, 8])

# %%
plot_contourf(rosenbrock_func, figsize=[8,8])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# Hàm Goldstein–Price được định nghĩa
#
# $$
# f(x, y) = \displaystyle\frac{\log{\left(1+{(x+y+1)}^2(19-14x+3x^2-14y+6xy+3y^2){(30+(2x-3y))}^2{(18-32x+12x^2+48y-36xy+27y^2)}^2\right)}}{10}
# $$

# %%
plot_cost_function_3d(goldstein_price_func, figsize=[12, 8])

# %%
plot_contourf(goldstein_price_func, figsize=[8,8])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
plot_cost_function_3d(rastrigin_func, figsize=[12, 8])

# %%
plot_contourf(rastrigin_func, figsize=[8,8])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
plot_cost_function_3d(ackley_func, figsize=[12, 8])

# %%
plot_contourf(ackley_func, figsize=[8,8])
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)
