# %%
# %matplotlib inline
from test_funcs import Beale, GoldsteinPrice, Rosenbrock
from visualizations import plot_cost_function_3d, plot_contourf

# %%
cost_f = Rosenbrock()

# %%
plot_cost_function_3d(cost_f)

# %%
plot_contourf(cost_f, figsize=[7,7])
# Out:
# [[ 314.28601051  295.58870073  261.85541736 ... 4746.03607778
#   5029.29394742 5174.78831107]
#  [ 308.48340053  289.97599901  256.64012858 ... 4727.23561795
#   5010.09351466 5155.38981731]
#  [ 302.34847511  284.02957592  251.06877862 ... 4708.3295343
#   4990.78962907 5135.88703073]
#  ...
#  [  56.9901781    46.17358552   28.2165129  ... 3952.08618879
#   4218.63420571 4355.77581521]
#  [  50.86209197   40.22735388   22.64569716 ... 3933.18010516
#   4199.33032013 4336.27304219]
#  [  45.12542964   34.62080299   17.44028669 ... 3914.37986348
#   4180.1300929  4316.87513838]]
# (<Figure size 504x504 with 1 Axes>, <AxesSubplot:>)
