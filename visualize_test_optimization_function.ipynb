# %%
from test_funcs import Beale
from visualizations import plot_cost_function_3d, plot_contourf

# %%
cost_f = Beale()

# %%
plot_cost_function_3d(cost_f)

# %%
plot_contourf(cost_f, figsize=[7,7])
# Out:
# [[0.0222414  0.02245351 0.0229902  ... 0.0197336  0.01970815 0.01969317]
#  [0.02236299 0.02256414 0.02308123 ... 0.02001949 0.01999388 0.01997864]
#  [0.02264528 0.02282774 0.02331409 ... 0.02060543 0.02057948 0.02056368]
#  ...
#  [0.04811451 0.04424843 0.04043893 ... 0.05943795 0.0600914  0.06073233]
#  [0.05529825 0.05288036 0.04955556 ... 0.05189825 0.05232234 0.05273646]
#  [0.05580791 0.05553621 0.05359568 ... 0.04877056 0.04911137 0.04944395]]
# (<Figure size 504x504 with 1 Axes>, <AxesSubplot:>)
