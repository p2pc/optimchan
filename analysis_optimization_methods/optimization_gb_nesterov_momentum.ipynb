# %%
from optimizers import GradientDescent, GradientDescentMomentum, GradientDescentNesterovMomentum, AdaGrad, AdaDelta, RMSProp, Adam
from optimizers.utils import run_optimizer
from test_funcs import Beale, GoldsteinPrice, Ackley, Rosenbrock, Easom
from visualizations import plot_evolution_charts, plot_cinematics_charts

# %%
# Khởi tạo số lần lặp và tốc độ học
iterations = 1500
learning_rate = 0.01

# %%
cost_f = Beale()
opt =  AdaGrad(cost_f=cost_f, lr=learning_rate)
errors_sgd, distance_sgd,xs_sgd, ys_sgd = run_optimizer(opt=opt, cost_f=cost_f, iterations=iterations)

# %%
plot_evolution_charts(cost_f, errors_sgd, distance_sgd, xs_sgd, ys_sgd)

# %%
plot_cinematics_charts(xs_sgd, ys_sgd)

# %%
goldstein_price_func = GoldsteinPrice()
opt = GradientDescentNesterovMomentum(cost_f=goldstein_price_func, lr=learning_rate)
errors_sgd, distance_sgd,xs_sgd, ys_sgd = run_optimizer(opt=opt, cost_f=goldstein_price_func, iterations=iterations)

# %%
plot_evolution_charts(goldstein_price_func, errors_sgd, distance_sgd, xs_sgd, ys_sgd)

# %%
plot_cinematics_charts(xs_sgd, ys_sgd)

# %%
from visualizations import global_compare

# %%
global_compare(cost_fnc=cost_f, learning_rate=learning_rate, iterations=iterations)
